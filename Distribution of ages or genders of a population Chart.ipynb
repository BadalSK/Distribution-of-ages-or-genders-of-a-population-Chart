# %%
pip install pandas matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# Create a dictionary with data
data = {
    'Age': np.random.randint(18, 80, size=100),  # Generate random ages between 18 and 80
    'Gender': np.random.choice(['Male', 'Female'], size=100)  # Generate random gender values
}

# Create a DataFrame from the dictionary
df = pd.DataFrame(data)

# Display the first few rows of the dataset
print(df.head())
# Out:
#    Age  Gender
# 0   68    Male
# 1   45  Female
# 2   26    Male
# 3   48    Male
# 4   49    Male

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     100 non-null    int32
#  1   Gender  100 non-null    object
# dtypes: int32(1), object(1)
# memory usage: 1.3+ KB

# %%
# Assuming your dataset has a column named 'Age' containing age values
ages = data['Age']

# Create a bar chart for age distribution
plt.figure(figsize=(12, 4))
age_series = df['Age']  # Extract the 'Age' column as a Pandas Series
age_series.value_counts().sort_index().plot(kind='bar', color='skyblue')
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age Distribution')
plt.xticks(rotation=0)
plt.show()

# Create a histogram for age distribution
plt.figure(figsize=(8, 4))
plt.hist(ages, bins=10, edgecolor='black', color='salmon')
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age Distribution (Histogram)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
